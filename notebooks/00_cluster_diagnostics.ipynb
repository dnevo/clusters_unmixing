# %% [markdown]
# # Cluster diagnostics and model run review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dnevo/clusters_unmixing/blob/main/notebooks/00_cluster_diagnostics.ipynb)
#
# This notebook mirrors the scope of the original project notebook, but targets the slimmed project layout.
#
# It covers:
# - running the configured correlation experiments
# - inspecting raw, normalized, and transformed cluster spectra
# - comparing off-diagonal correlation statistics
# - reviewing model metrics
# - previewing abundance estimates and synthetic pixel spectra

# %%
import subprocess
import sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    project_root = Path("/content/clusters_unmixing")
    if not project_root.exists():
        subprocess.check_call([
            "git",
            "clone",
            "https://github.com/dnevo/clusters_unmixing.git",
            str(project_root),
        ])
else:
    NOTEBOOK_DIR = Path.cwd()
    project_root = NOTEBOOK_DIR.parent

SRC_DIR = project_root / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from clusters_unmixing.utils import run_diagnostics_notebook
run_diagnostics_notebook(project_root=project_root)
# Out:
# Epoch    1 | train=8.959176e-02 | val=9.079298e-02 | val_abund=5.466321e-02 | val_recon=3.612977e-01
# Epoch   20 | train=3.800509e-02 | val=4.192498e-02 | val_abund=4.043243e-02 | val_recon=1.492552e-02
# Epoch   40 | train=3.237478e-02 | val=3.631619e-02 | val_abund=3.548937e-02 | val_recon=8.268232e-03
# Epoch   60 | train=2.861478e-02 | val=3.060783e-02 | val_abund=2.992240e-02 | val_recon=6.854323e-03
# Epoch   80 | train=2.625488e-02 | val=2.777982e-02 | val_abund=2.707993e-02 | val_recon=6.998944e-03
# Epoch  100 | train=2.553138e-02 | val=2.670500e-02 | val_abund=2.603273e-02 | val_recon=6.722735e-03
# Epoch  120 | train=2.483259e-02 | val=2.628541e-02 | val_abund=2.562623e-02 | val_recon=6.591890e-03
# Epoch  140 | train=2.398454e-02 | val=2.579307e-02 | val_abund=2.515549e-02 | val_recon=6.375721e-03
# Epoch  160 | train=2.351675e-02 | val=2.557772e-02 | val_abund=2.492242e-02 | val_recon=6.553051e-03
# Epoch  180 | train=2.319695e-02 | val=2.504863e-02 | val_abund=2.443481e-02 | val_recon=6.138205e-03
# Epoch  200 | train=2.298228e-02 | val=2.483777e-02 | val_abund=2.423952e-02 | val_recon=5.982457e-03
# Epoch  220 | train=2.249507e-02 | val=2.448509e-02 | val_abund=2.389004e-02 | val_recon=5.950568e-03
# Epoch  240 | train=2.210810e-02 | val=2.435145e-02 | val_abund=2.376565e-02 | val_recon=5.858012e-03
# Epoch  260 | train=2.211104e-02 | val=2.402841e-02 | val_abund=2.345109e-02 | val_recon=5.773280e-03
# Epoch  280 | train=2.166206e-02 | val=2.424856e-02 | val_abund=2.368487e-02 | val_recon=5.636859e-03
# **Experiment name:** `cluster_corr_options`
#
# **Output dir:** `H:\repos\clusters_unmixing\experiments\outputs\cluster_corr_options`
# ---
# ## Run 1/2
#                                                 value
# cluster set                          6clusters_thomas
# bands          0.5-0.8 none, 1.2-1.6 mean, 2-2.5 none
# normalization                          with_quadratic
# transform                         pca(n_components=5)
# pixels                                           1024
# snr                                             20 dB
# models                       sunsal, vpgdu, small_mlp
#             mean_abs_offdiag  max_abs_offdiag  min_offdiag  max_offdiag
# stage
# raw                 0.996241         0.999652     0.986813     0.999652
# normalized          0.704036         0.998961    -0.948268     0.998961
# pca                 0.704110         0.998977    -0.948268     0.998977
# ### Model metrics
# model           small_mlp    sunsal     vpgdu
# metric
# abundance_mae    0.105595  0.144367  0.148519
# abundance_rmse   0.149005  0.221264  0.227769
# ### Abundances  |  pixel_index=27
#       source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0       true                0.000000     0.000000     0.000000      0.00000     0.000000     0.000000     1.000000
# 1  small_mlp                0.017334     0.007528     0.001020      0.01246     0.008056     0.008948     0.961987
# 2     sunsal                0.072544    -0.011412    -0.011602     -0.00291    -0.003773     0.139040     0.890657
# 3      vpgdu                0.050073     0.006879     0.000000      0.00000     0.000000     0.083084     0.910036
# ### Abundances  |  pixel_index=77
#       source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0       true                0.000000     1.000000     0.000000     0.000000     0.000000     0.000000     0.000000
# 1  small_mlp                0.124759     0.740387     0.149993     0.010957     0.041707     0.030714     0.026242
# 2     sunsal                0.004194     1.003208    -0.003363    -0.004049    -0.001799    -0.001809     0.007813
# 3      vpgdu                0.030090     0.947882     0.052118     0.000000     0.000000     0.000000     0.000000
# ### Abundances  |  pixel_index=320
#       source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0       true                0.000000     0.000000     0.000000     0.100000     0.000000     0.900000     0.000000
# 1  small_mlp                0.132074     0.032044     0.031974     0.056601     0.072904     0.639884     0.166593
# 2     sunsal                0.070934    -0.000300    -0.000069     0.000116     0.137278     0.863019    -0.000044
# 3      vpgdu                0.227648     0.000000     0.143641     0.000000     0.044794     0.485384     0.326181
# ### Abundances  |  pixel_index=609
#       source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0       true                0.000000     0.000000     0.100000     0.000000     0.000000     0.000000     0.900000
# 1  small_mlp                0.049625     0.023453     0.004854     0.027057     0.023911     0.053108     0.867618
# 2     sunsal                0.001974     0.000052     0.103448    -0.000120     0.000079    -0.000074     0.896615
# 3      vpgdu                0.088367     0.000000     0.000000     0.054922     0.000000     0.150639     0.794438
# ### Abundances  |  pixel_index=927
#       source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0       true                0.000000     0.300000     0.100000     0.100000     0.100000     0.300000     0.100000
# 1  small_mlp                0.090004     0.241994     0.110666     0.053863     0.269794     0.186825     0.136859
# 2     sunsal                0.189373     0.438230     0.179229    -0.000153     0.000229    -0.000014     0.382479
# 3      vpgdu                0.277341     0.037131     0.532248     0.000000     0.016593     0.000000     0.414028
# ### Synthetic pixel spectra preview
# ---
# ## Run 2/2
#                           value
# cluster set    6clusters_thomas
# bands              0.5-2.5 none
# normalization    with_quadratic
# transform                   raw
# pixels                      256
# snr                       30 dB
# models                   sunsal
#             mean_abs_offdiag  max_abs_offdiag  min_offdiag  max_offdiag
# stage
# raw                 0.998319         0.999835     0.994246     0.999835
# normalized          0.724317         0.998485    -0.928887     0.998485
# ### Model metrics
# model             sunsal
# metric
# abundance_mae   0.043155
# abundance_rmse  0.064355
# ### Abundances  |  pixel_index=83
#    source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0    true                0.000000     0.200000      0.60000     0.000000     0.000000     0.200000     0.000000
# 1  sunsal                0.168177     0.372998      0.36257     0.076655     0.192277    -0.001354    -0.003146
# ### Abundances  |  pixel_index=101
#    source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0    true                0.000000     0.300000     0.400000     0.200000     0.100000     0.000000     0.000000
# 1  sunsal                0.045217     0.252577     0.453434     0.212563     0.032262     0.049167    -0.000002
# ### Abundances  |  pixel_index=150
#    source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0    true                0.000000     0.400000     0.100000     0.100000     0.000000     0.300000     0.100000
# 1  sunsal                0.076859     0.470442     0.007563     0.177785     0.032241     0.181914     0.130055
# ### Abundances  |  pixel_index=158
#    source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0    true                 0.00000     0.400000     0.000000      0.00000     0.000000     0.300000      0.30000
# 1  sunsal                 0.07075     0.353404    -0.000627      0.00142    -0.001064     0.439106      0.20776
# ### Abundances  |  pixel_index=170
#    source  abundance_rmse_vs_true  endmember_1  endmember_2  endmember_3  endmember_4  endmember_5  endmember_6
# 0    true                0.000000     0.100000     0.000000     0.000000     0.500000     0.000000     0.400000
# 1  sunsal                0.024991     0.099674     0.000003     0.013829     0.463461     0.042787     0.380245
# ### Synthetic pixel spectra preview
