# %% [markdown]
# # Cluster diagnostics and model run review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dnevo/clusters_unmixing/blob/main/notebooks/00_cluster_diagnostics.ipynb)
#
# This notebook mirrors the scope of the original project notebook, but targets the slimmed project layout.
#
# It covers:
# - running the configured correlation experiments
# - inspecting raw, normalized, and transformed cluster spectra
# - comparing off-diagonal correlation statistics
# - reviewing model metrics
# - previewing abundance estimates and synthetic pixel spectra

# %%
import subprocess
import sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    PROJECT_ROOT = Path("/content/clusters_unmixing")
    if not PROJECT_ROOT.exists():
        subprocess.check_call([
            "git",
            "clone",
            "https://github.com/dnevo/clusters_unmixing.git",
            str(PROJECT_ROOT),
        ])
else:
    NOTEBOOK_DIR = Path.cwd()
    PROJECT_ROOT = NOTEBOOK_DIR.parent if NOTEBOOK_DIR.name == "notebooks" else NOTEBOOK_DIR

SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from clusters_unmixing.utils import configure_notebook, run_diagnostics_notebook

root = configure_notebook(project_root=PROJECT_ROOT)
CONFIG_PATH =  root / 'experiments' / 'configs' / 'correlation_options.yaml'

# %%
artifacts = run_diagnostics_notebook(config_path=CONFIG_PATH, project_root=PROJECT_ROOT)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 artifacts = run_diagnostics_notebook(config_path=CONFIG_PATH, project_root=PROJECT_ROOT)
#
# File h:\repos\clusters_unmixing\src\clusters_unmixing\utils\notebook_diagnostics.py:139, in run_diagnostics_notebook(config_path, project_root)
#     136 root = configure_notebook(project_root=project_root)
#     137 resolved_config = Path(config_path).resolve() if config_path is not None else default_config_path(root)
# --> 139 result = run_correlation_experiments(resolved_config)
#     140 config = ExperimentConfig.from_file(resolved_config)
#     141 cluster_paths = _cluster_path_map(config, project_root=root)
#
# File h:\repos\clusters_unmixing\src\clusters_unmixing\pipelines\correlation_pipeline.py:112, in run_correlation_experiments(config_path)
#     111 def run_correlation_experiments(config_path: str | Path) -> dict[str, Any]:
# --> 112     exp = ExperimentConfig.from_json_file(config_path)
#     113     output_dir = _resolve_output_dir(exp) / exp.run_name
#     114     output_dir.mkdir(parents=True, exist_ok=True)
#
# File h:\envs\research_base\Lib\site-packages\pydantic\_internal\_model_construction.py:289, in ModelMetaclass.__getattr__(self, item)
#     287 if private_attributes and item in private_attributes:
#     288     return private_attributes[item]
# --> 289 raise AttributeError(item)
#
# AttributeError: from_json_file
